# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from copulas.multivariate import GaussianMultivariate
from copulas.visualization import compare_3d
from copulas.visualization import scatter_3d
from copulas.multivariate import VineCopula
from copulas.bivariate import Gumbel
from copulas.bivariate import Clayton
from copulas.bivariate import Frank
from copulas.visualization import scatter_2d
from copulas.visualization import compare_2d
from sdv.evaluation import evaluate
# %matplotlib inline

# %% [markdown]
# ## Loading Dataset

# %% [markdown]
# #### naming columns

# %%
col = ['no','x','y','z','c']
use=list(np.arange(len(col)))
#path = '../Data/dataset_4_classes/'

# %% [markdown]
# #### read the csv file

# %% [markdown]
# ## Phone Accelerometer

# %%
# Phone Accelerometer
p_acc= pd.read_csv('p_acc_9000.csv',delimiter=",",skiprows=1,names=col,na_filter=True,na_values=-200,usecols=use)
print(len(p_acc))
p_acc.head()
# Out:
# 9000
#      no         x         y         z           c
# 0  2500 -3.459992  0.636887  8.598328  stairsdown
# 1  2501 -3.062470  0.339340  8.528107  stairsdown
# 2  2502 -2.767304  0.091782  8.436462  stairsdown
# 3  2503 -2.525696 -0.073654  8.381714  stairsdown
# 4  2504 -2.468567 -0.225998  8.281738  stairsdown

# %%
# %matplotlib inline
sns.distplot(p_acc['x'], hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
# %matplotlib inline
sns.distplot(p_acc['y'], hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
# %matplotlib inline
sns.distplot(p_acc['z'], hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %% [markdown]
# ## Phone Gyroscope

# %%
# Phone Gyroscope
p_gyr= pd.read_csv('p_gyr_9000.csv',delimiter=",",skiprows=1,names=col,na_filter=True,na_values=-200,usecols=use)
print(len(p_gyr))
p_gyr.head()
# Out:
# 9000
#      no         x         y         z           c
# 0  7500 -0.085144 -0.681671  0.603180  stairsdown
# 1  7501 -0.009308 -0.599426  0.510254  stairsdown
# 2  7502  0.078278 -0.501160  0.404510  stairsdown
# 3  7503  0.150909 -0.364441  0.299835  stairsdown
# 4  7504  0.194702 -0.187134  0.200500  stairsdown

# %%
# %matplotlib inline
sns.distplot(p_gyr['x'], hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
# %matplotlib inline
sns.distplot(p_gyr['y'], hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
# %matplotlib inline
sns.distplot(p_gyr['z'], hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %% [markdown]
# ## Watch Accelerometer

# %%
# Watch Accelerometer
w_acc= pd.read_csv('w_acc_9000.csv',delimiter=",",skiprows=1,names=col,na_filter=True,na_values=-200,usecols=use)
print(len(w_acc))
w_acc.head()
# Out:
# 9000
#      no         x         y         z           c
# 0  5000 -8.499039 -3.864410  2.253403  stairsdown
# 1  5001 -8.791824 -3.935821  2.272446  stairsdown
# 2  5002 -9.065567 -4.042938  2.215317  stairsdown
# 3  5003 -9.294083 -4.054840  2.234360  stairsdown
# 4  5004 -9.570206 -4.114349  2.258164  stairsdown

# %%
# %matplotlib inline
sns.distplot(w_acc['x'], hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
# %matplotlib inline
sns.distplot(w_acc['y'], hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
# %matplotlib inline
sns.distplot(w_acc['z'], hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %% [markdown]
# ## Watch Gyroscope

# %%
# Watch gyroscope
w_gyr= pd.read_csv('w_gyr_9000.csv',delimiter=",",skiprows=1,names=col,na_filter=True,na_values=-200,usecols=use)
print(len(w_gyr))
w_gyr.head()
# Out:
# 9000
#      no         x         y         z           c
# 0  7500 -0.198105  0.259308  0.912903  stairsdown
# 1  7501 -0.257919  0.228333  0.904358  stairsdown
# 2  7502 -0.313461  0.204834  0.896881  stairsdown
# 3  7503 -0.352982  0.178131  0.884064  stairsdown
# 4  7504 -0.383957  0.163177  0.871246  stairsdown

# %%
# %matplotlib inline
sns.distplot(w_gyr['x'], hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
# %matplotlib inline
sns.distplot(w_gyr['y'], hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
# %matplotlib inline
sns.distplot(w_gyr['z'], hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
cnt = {'stairsdown':0,'stairsup':0,'sit':0,'stand':0,'walk':0,'bike':0}
for i in w_gyr['c']:
    if i == 'stairsdown':
        cnt['stairsdown'] += 1
    elif i == 'stairsup':
        cnt['stairsup'] += 1
    elif i == 'sit':
        cnt['sit'] += 1
    elif i == 'stand':
        cnt['stand'] += 1
    elif i == 'walk':
        cnt['walk'] += 1
    elif i == 'bike':
        cnt['bike'] += 1

# %%
cnt
# Out:
# {'stairsdown': 1500,
#  'stairsup': 1500,
#  'sit': 1500,
#  'stand': 1500,
#  'walk': 1500,
#  'bike': 1500}

# %% [markdown]
# #### function to find names of classes

# %%
list(set(p_acc['c']))
# Out:
# ['walk', 'stairsdown', 'sit', 'stand', 'bike', 'stairsup']

# %%
list(set(p_gyr['c']))
# Out:
# ['walk', 'stairsdown', 'sit', 'stand', 'bike', 'stairsup']

# %% [markdown]
# #### Dropping unnecessary columns for fit

# %%
d1 = p_acc
label1 = p_acc['c']
d1 = d1.drop('c',axis=1)
d1 = d1.drop('no',axis=1)
print(len(d1))
# Out:
# 9000

# %%
d2 = p_gyr
label2 = p_gyr['c']
d2 = d2.drop('c',axis=1)
d2 = d2.drop('no',axis=1)
print(len(d2))
# Out:
# 9000

# %%
d3 = w_acc
label3 = w_acc['c']
d3 = d3.drop('c',axis=1)
d3 = d3.drop('no',axis=1)
print(len(d3))
# Out:
# 9000

# %%
d4 = w_gyr
label4 = w_gyr['c']
d4 = d4.drop('c',axis=1)
d4 = d4.drop('no',axis=1)
print(len(d3))
# Out:
# 9000

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
target= label_encoder.fit_transform(label1)

# %%
target = pd.DataFrame(target,columns = ['target'])
target
# Out:
#       target
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2
# ...      ...
# 8995       0
# 8996       0
# 8997       0
# 8998       0
# 8999       0
#
# [9000 rows x 1 columns]

# %%
df1 = pd.concat([d1,d2,d3,d4,target],axis=1)
df1.columns = ['p_acc_x','p_acc_y','p_acc_z','p_gyr_x','p_gyr_y','p_gyr_z','w_acc_x','w_acc_y','w_acc_z','w_gyr_x','w_gyr_y','w_gyr_z','target']
df1
# Out:
#        p_acc_x   p_acc_y    p_acc_z   p_gyr_x   p_gyr_y   p_gyr_z   w_acc_x  \
# 0    -3.459992  0.636887   8.598328 -0.085144 -0.681671  0.603180 -8.499039
# 1    -3.062470  0.339340   8.528107 -0.009308 -0.599426  0.510254 -8.791824
# 2    -2.767304  0.091782   8.436462  0.078278 -0.501160  0.404510 -9.065567
# 3    -2.525696 -0.073654   8.381714  0.150909 -0.364441  0.299835 -9.294083
# 4    -2.468567 -0.225998   8.281738  0.194702 -0.187134  0.200500 -9.570206
# ...        ...       ...        ...       ...       ...       ...       ...
# 8995 -3.429047  1.305771   7.834229 -0.124191 -0.118942  0.171387 -9.565445
# 8996 -2.899414  0.957047   8.676880 -0.129532 -0.132828  0.159637 -9.377396
# 8997 -2.899414  0.957047   8.676880 -0.129532 -0.125351  0.164978 -8.887039
# 8998 -3.264801  0.903488   9.924194 -0.126328 -0.140305  0.153229 -8.015823
# 8999 -3.430237  0.823746  10.194366 -0.123123 -0.146713  0.141479 -7.130325
#
# ...

# %%
# %matplotlib notebook
sns.heatmap(df1.corr(),annot=True,cmap='viridis')
#plt.title('Heatmap after fusion with labels - Rvine',fontsize=16)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="732.4444444444445">

# %%
df2 = pd.concat([d1,d2,d3,d4,label1],axis=1)
df2.columns = ['p_acc_x','p_acc_y','p_acc_z','p_gyr_x','p_gyr_y','p_gyr_z','w_acc_x','w_acc_y','w_acc_z','w_gyr_x','w_gyr_y','w_gyr_z','label']
df2
# Out:
#        p_acc_x   p_acc_y    p_acc_z   p_gyr_x   p_gyr_y   p_gyr_z   w_acc_x  \
# 0    -3.459992  0.636887   8.598328 -0.085144 -0.681671  0.603180 -8.499039
# 1    -3.062470  0.339340   8.528107 -0.009308 -0.599426  0.510254 -8.791824
# 2    -2.767304  0.091782   8.436462  0.078278 -0.501160  0.404510 -9.065567
# 3    -2.525696 -0.073654   8.381714  0.150909 -0.364441  0.299835 -9.294083
# 4    -2.468567 -0.225998   8.281738  0.194702 -0.187134  0.200500 -9.570206
# ...        ...       ...        ...       ...       ...       ...       ...
# 8995 -3.429047  1.305771   7.834229 -0.124191 -0.118942  0.171387 -9.565445
# 8996 -2.899414  0.957047   8.676880 -0.129532 -0.132828  0.159637 -9.377396
# 8997 -2.899414  0.957047   8.676880 -0.129532 -0.125351  0.164978 -8.887039
# 8998 -3.264801  0.903488   9.924194 -0.126328 -0.140305  0.153229 -8.015823
# 8999 -3.430237  0.823746  10.194366 -0.123123 -0.146713  0.141479 -7.130325
#
# ...

# %%
#import ppscore as pps
#pps.predictors(df2, "label")

# %%
import ppscore as pps
x = pps.matrix(df2,sample=9000)[['x','y','ppscore']].pivot(columns='x',index='y',values='ppscore')

# %%
# %matplotlib notebook
sns.heatmap(x,annot=True,cmap='Blues')
#plt.title('Heatmap after fusion with labels-Rvine',fontsize=16)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="688">

# %%
w_acc_z = d3['z']
w_acc_z
# Out:
# 0       2.253403
# 1       2.272446
# 2       2.215317
# 3       2.234360
# 4       2.258164
#           ...
# 8995    6.152451
# 8996    6.342880
# 8997    6.209580
# 8998    6.219101
# 8999    6.073898
# Name: z, Length: 9000, dtype: float64

# %%
p_gyr_x = d2['x']
p_gyr_x
# Out:
# 0      -0.085144
# 1      -0.009308
# 2       0.078278
# 3       0.150909
# 4       0.194702
#           ...
# 8995   -0.124191
# 8996   -0.129532
# 8997   -0.129532
# 8998   -0.126328
# 8999   -0.123123
# Name: x, Length: 9000, dtype: float64

# %%
d3 = d3.drop('z',axis=1)
d3
# Out:
#              x         y
# 0    -8.499039 -3.864410
# 1    -8.791824 -3.935821
# 2    -9.065567 -4.042938
# 3    -9.294083 -4.054840
# 4    -9.570206 -4.114349
# ...        ...       ...
# 8995 -9.565445 -2.462372
# 8996 -9.377396 -2.248138
# 8997 -8.887039 -1.988678
# 8998 -8.015823 -1.907745
# 8999 -7.130325 -1.938690
#
# [9000 rows x 2 columns]

# %%
d2 = d2.drop('x',axis=1)
d2
# Out:
#              y         z
# 0    -0.681671  0.603180
# 1    -0.599426  0.510254
# 2    -0.501160  0.404510
# 3    -0.364441  0.299835
# 4    -0.187134  0.200500
# ...        ...       ...
# 8995 -0.118942  0.171387
# 8996 -0.132828  0.159637
# 8997 -0.125351  0.164978
# 8998 -0.140305  0.153229
# 8999 -0.146713  0.141479
#
# [9000 rows x 2 columns]

# %% [markdown]
# ## Fitting Copula

# %% [markdown]
# ### Phone Accelerometer

# %%
regular = VineCopula('regular')
regular.fit(d1)
# Out:
# c:\users\jahna\appdata\local\programs\python\python37\lib\site-packages\copulas\bivariate\base.py:160: RuntimeWarning: Data does not appear to be uniform.
#   warnings.warn("Data does not appear to be uniform.", category=RuntimeWarning)

# %%
parameters = regular.to_dict()
parameters.keys()
# Out:
# dict_keys(['type', 'vine_type', 'fitted', 'n_sample', 'n_var', 'depth', 'truncated', 'trees', 'tau_mat', 'u_matrix', 'unis', 'columns'])

# %%
tau_mat = parameters['tau_mat']
tau_mat
# Out:
# [[1.0, -0.26275196738329837, 0.08583235537903829],
#  [-0.26275196738329837, 1.0, -0.16794664691864578],
#  [0.08583235537903829, -0.16794664691864578, 1.0]]

# %%
u_matrix = parameters['u_matrix']
u_matrix
# Out:
# [[0.715645936751573, 0.6449000001490783, 0.5217774617900202],
#  [0.7534218232938048, 0.5321198203929216, 0.5042756349733994],
#  [0.7768709794395686, 0.46105334044672763, 0.47990087073114507],
#  [0.7925114753551079, 0.4221464321465671, 0.46471089629181883],
#  [0.7957247973570499, 0.38712958478945747, 0.4363838173573106],
#  [0.7925114753551079, 0.36444860302758014, 0.4282808538645692],
#  [0.7859100471019342, 0.3340170818180809, 0.38376781488246337],
#  [0.7849124537174841, 0.29715032028133737, 0.365698177033098],
#  [0.776015408553922, 0.24001959764031372, 0.31397625187283473],
#  [0.7534218232938048, 0.16787718383251, 0.25473436778701364],
#  [0.7614778421080755, 0.21161744506340732, 0.2922502032122951],
#  [0.7403282654879295, 0.15643268812609548, 0.24286551081308252],
#  [0.7254449419312501, 0.14526790584527627, 0.21883880680850495],
#  [0.7254449419312501, 0.15075101043615644, 0.1911697924198612],
#  [0.7134582511375235, 0.15161242149975496, 0.18117473739505177],
# ...

# %%
t = parameters['trees']
len(t)
# Out:
# 2

# %% [markdown]
# ## Uniform marginal distributions

# %%
F1 = []
F2 = []
F3 = []
for i in range(len(parameters['u_matrix'])):
    F1.append(parameters['u_matrix'][i][0])
    F2.append(parameters['u_matrix'][i][1])
    F3.append(parameters['u_matrix'][i][2])

# %%
# %matplotlib inline
sns.distplot(F1, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
sns.distplot(F2, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
sns.distplot(F3, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %% [markdown]
# ## Marginal pdfs

# %%
f1 = regular.unis[0].probability_density(d1['x'])

# %%
f2 = regular.unis[1].probability_density(d1['y'])

# %%
f3 = regular.unis[2].probability_density(d1['z'])

# %%
# %matplotlib inline
ax = sns.distplot(f1, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="f1", ylabel = "marginal density")
# Out:
# [Text(0, 0.5, 'marginal density'), Text(0.5, 0, 'f1')]

# %%
# %matplotlib inline
sns.distplot(f2, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
# %matplotlib inline
sns.distplot(f3, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %% [markdown]
# ## Tree Structure

# %%
trees = parameters['trees']
print('Number of the trees:',len(trees))
# Out:
# Number of the trees: 2

# %%
d1_r12 = trees[0]['edges'][0]
d1_r23 = trees[0]['edges'][1]
d1_r13_2 = trees[1]['edges'][0]

# %%
print('r12:',d1_r12['name'],'r23:',d1_r23['name'])
print('r13|2:',d1_r13_2['name'])
# Out:
# r12: CopulaTypes.FRANK r23: CopulaTypes.FRANK
# r13|2: CopulaTypes.FRANK

# %% [markdown]
# ### Frank12

# %%
print(d1_r12.keys())
# Out:
# dict_keys(['index', 'L', 'R', 'D', 'parents', 'neighbors', 'name', 'theta', 'tau', 'U', 'likelihood'])

# %%
print(d1_r12['tau'])
# Out:
# -0.26275196738329837

# %%
print(d1_r12['theta'])
# Out:
# -2.507376315015066

# %%
d1_r12_marginal_data = np.array([d1_r12['U'][0],d1_r12['U'][1]])

# %%
d1_r12_marginal_data
# Out:
# array([[0.80153666, 0.7901975 , 0.78418816, ..., 0.87721736, 0.85081262,
#         0.83021927],
#        [0.77052034, 0.68578393, 0.62673388, ..., 0.87272255, 0.85284223,
#         0.82855545]])

# %%
d1_r12_marginal_data1 = []
for i in range(len(d1_r12['U'][0])):
    sin = []
    sin.append(d1_r12_marginal_data[0][i])
    sin.append(d1_r12_marginal_data[1][i])
    d1_r12_marginal_data1.append(sin)

# %%
d1_r12_marginal_data1 = np.array(d1_r12_marginal_data1)

# %%
frank = Frank()
frank.tau = d1_r12['tau']
frank.theta = d1_r12['theta']
d1_joint_r12 = frank.probability_density(d1_r12_marginal_data1)
len(d1_joint_r12)
# Out:
# 9000

# %%
# %matplotlib inline
ax = sns.distplot(d1_joint_r12, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="values after fusion", ylabel = "probability density")
ax.set(title = "Joint Probabilty Density plot of Frank12")
# Out:
# [Text(0.5, 1.0, 'Joint Probabilty Density plot of Frank12')]

# %%
# defining the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
  
# No of data points used
N = 9000
  
# normal distribution
data = d1_joint_r12
  
# sort the data in ascending order
x = np.sort(data)
  
# get the cdf values of y
y = np.arange(N) / float(N)
  
# plotting
plt.xlabel('values')
plt.ylabel('cdf')
  
plt.title('Joint cumulative distribution of Frank12')
  
plt.plot(x, y)

# %% [markdown]
# ### Frank23

# %%
d1_r23_marginal_data = np.array([d1_r23['U'][0],d1_r23['U'][1]])

# %%
d1_r23_marginal_data1 = []
for i in range(len(d1_r23['U'][0])):
    sin = []
    sin.append(d1_r23_marginal_data[0][i])
    sin.append(d1_r23_marginal_data[1][i])
    d1_r23_marginal_data1.append(sin)

# %%
d1_r23_marginal_data1 = np.array(d1_r23_marginal_data1)

# %%
print(d1_r23['tau'])
print(d1_r23['theta'])
# Out:
# -0.16794664691864578
# -1.5471092570614982

# %%
frank = Frank()
frank.tau = d1_r23['tau']
frank.theta = d1_r23['theta']
d1_joint_r23 = frank.probability_density(d1_r23_marginal_data1)
len(d1_joint_r23)
# Out:
# 9000

# %%
print(d1_joint_r23[0:10])
# Out:
# [0.98972649 1.04638165 1.04114655 1.01993923 0.9803963  0.95688987
#  0.89059466 0.83830291 0.73459584 0.62387391]

# %%
# %matplotlib inline
ax = sns.distplot(d1_joint_r23, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="values after fusion", ylabel = "probability density")
ax.set(title="Joint Probability density plot of Frank c23")
# Out:
# [Text(0.5, 1.0, 'Joint Probability density plot of Frank c23')]

# %%
# No of data points used
N = 9000
  
# normal distribution
data = d1_joint_r23
  
# sort the data in ascending order
x = np.sort(data)
  
# get the cdf values of y
y = np.arange(N) / float(N)
  
# plotting
plt.xlabel('values')
plt.ylabel('cdf')
  
plt.title('Joint cumulative distribution of Frank c23')
  
plt.plot(x, y)

# %% [markdown]
# ### Frank13|2

# %%
d1_r13_2_marginal_data = np.array([d1_r13_2['U'][0],d1_r13_2['U'][1]])
d1_r13_2_marginal_data1 = []
for i in range(len(d1_r13_2['U'][0])):
    sin = []
    sin.append(d1_r13_2_marginal_data[0][i])
    sin.append(d1_r13_2_marginal_data[1][i])
    d1_r13_2_marginal_data1.append(sin)
d1_r13_2_marginal_data1 = np.array(d1_r13_2_marginal_data1)

# %%
print(d1_r13_2['tau'])
print(d1_r13_2['theta'])
# Out:
# -0.26275223011334714
# 0.6400832907064632

# %%
frank = Frank()
frank.tau = d1_r13_2['tau']
frank.theta = d1_r13_2['theta']
d1_joint_r13_2 = frank.probability_density(d1_r13_2_marginal_data1)
len(d1_joint_r13_2)
# Out:
# 9000

# %%
print(d1_joint_r13_2[0:10])
# Out:
# [1.01146179 0.98892539 0.96963898 0.95769993 0.9445482  0.94234063
#  0.92949209 0.92576621 0.91981284 0.92932541]

# %%
ax = sns.distplot(d1_joint_r13_2, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="values after fusion", ylabel = "probability density")
ax.set(title="Joint Probability density plot of Frank c13|2")
# Out:
# [Text(0.5, 1.0, 'Joint Probability density plot of Frank c13|2')]

# %%
# No of data points used
N = 9000
  
# normal distribution
data = d1_joint_r13_2
  
# sort the data in ascending order
x = np.sort(data)
  
# get the cdf values of y
y = np.arange(N) / float(N)
  
# plotting
plt.xlabel('values')
plt.ylabel('cdf')
  
plt.title('Joint cumulative distribution of Frank c13|2')
  
plt.plot(x, y)

# %% [markdown]
# ### Joint density using pair copula function equation

# %% [markdown]
# joint_p_acc = f3.f2.f1. joint_c12 . joint_c13 . joint_c23_1

# %%
joint_p_acc = [f3[i]*f2[i]*f1[i]*d1_joint_r12[i]*d1_joint_r23[i]*d1_joint_r13_2[i] for i in range(len(F1))]

# %%
print(joint_p_acc)
# Out:
# [0.00580519319510282, 0.0055614511652480455, 0.003956669962606873, 0.003084595133129403, 0.0031416532814081462, 0.0037651230319089087, 0.004486790985625218, 0.005113075406586656, 0.0041255658139747586, 0.0018746761933307017, 0.00342236805853849, 0.001665450462763678, 0.0014384293463832116, 0.00157493651617746, 0.001637255285032918, 0.0022179384071412287, 0.00204044597514763, 0.0014204405908438767, 0.0010209749238985198, 0.0008510681478575266, 0.0007829418018746424, 0.0007975341812084059, 0.0008041584953760095, 0.0008894807963093278, 0.0011818995338011501, 0.0014708906858535915, 0.002063917561433026, 0.002281653703650256, 0.00047489226699691436, 0.00021980616513198292, 0.000168139465807075, 0.0001231866116503296, 9.805436532028546e-05, 0.00010330938417275375, 0.00011892625788905502, 0.0001276440754851698, 0.0003441474179131637, 0.0019371160392300378, 0.001178134005627862, 0.0014163493495151641, 0.00011882169058287599, 3.8605196715546996e-05, 2.7663146212114233e-05, 1.7146490496052633e
# ...

# %%
print(len(joint_p_acc))
# Out:
# 9000

# %%
ax = sns.distplot(joint_p_acc, hist=True, kde=True, 
             bins=int(180/5), color = 'pink', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="values after fusion", ylabel = "probability density")
# Out:
# [Text(0, 0.5, 'probability density'), Text(0.5, 0, 'values after fusion')]

# %%
# defining the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
  
# No of data points used
N = 9000
  
# normal distribution
data = joint_p_acc
  
# sort the data in ascending order
x = np.sort(data)
  
# get the cdf values of y
y = np.arange(N) / float(N)
  
# plotting
plt.xlabel('values')
plt.ylabel('cdf')
  
plt.title('Joint cumulative distribution of Phone Accelerometer')
  
plt.plot(x, y)

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Fitting Copula

# %% [markdown]
# ### Phone Gyroscope

# %%
regular = VineCopula('regular')
regular.fit(d2)

# %%
parameters = regular.to_dict()
parameters.keys()
# Out:
# dict_keys(['type', 'vine_type', 'fitted', 'n_sample', 'n_var', 'depth', 'truncated', 'trees', 'tau_mat', 'u_matrix', 'unis', 'columns'])

# %%
tau_mat = parameters['tau_mat']
tau_mat
# Out:
# [[1.0, -0.10357319444727947], [-0.10357319444727947, 1.0]]

# %%
u_matrix = parameters['u_matrix']
u_matrix
# Out:
# [[0.08588522041467006, 0.9054236086832674],
#  [0.10669266425073778, 0.8832177741771403],
#  [0.13639377388839494, 0.853257456042928],
#  [0.18244056268271433, 0.8169159686870172],
#  [0.25395804006629746, 0.7759959281465744],
#  [0.5793861774725468, 0.7088322368552905],
#  [0.796195809595775, 0.5560107122768259],
#  [0.870629026752927, 0.35576319969111275],
#  [0.9213280131362047, 0.2597449404579736],
#  [0.9509670305394301, 0.20357366454381168],
#  [0.9697645588868246, 0.15515132193264267],
#  [0.9894098837054388, 0.08355828864723584],
#  [0.9817618167467647, 0.11157784404564011],
#  [0.9933361122940021, 0.06635885216823002],
#  [0.9951904795984242, 0.05903475302005348],
#  [0.9956855486886423, 0.06005110133385828],
#  [0.9949778534240072, 0.06896322768971644],
#  [0.9929929588212902, 0.08870244113425409],
#  [0.9898451889795343, 0.12088412284006878],
#  [0.9846052940911861, 0.15925926895645964],
#  [0.9748538143266282, 0.1979960293249443],
# ...

# %% [markdown]
# ## Tree Structure

# %%
trees = parameters['trees']
print('Number of the trees:',len(trees))
# Out:
# Number of the trees: 1

# %%
d2_r12 = trees[0]['edges'][0]

# %%
print('r12:',d2_r12['name'])
# Out:
# r12: CopulaTypes.FRANK

# %% [markdown]
# ## Marginal densities

# %%
f1 = regular.unis[0].probability_density(d2['y'])

# %%
f2 = regular.unis[1].probability_density(d2['z'])

# %% [markdown]
# ### Frank12

# %%
print(d2_r12.keys())
# Out:
# dict_keys(['index', 'L', 'R', 'D', 'parents', 'neighbors', 'name', 'theta', 'tau', 'U', 'likelihood'])

# %%
print(d2_r12['tau'])
# Out:
# -0.10357319444727947

# %%
print(d2_r12['theta'])
# Out:
# -0.9403466058930503

# %%
d2_r12_marginal_data = np.array([d2_r12['U'][0],d2_r12['U'][1]])

# %%
d2_r12_marginal_data1 = []
for i in range(len(d2_r12['U'][0])):
    sin = []
    sin.append(d2_r12_marginal_data[0][i])
    sin.append(d2_r12_marginal_data[1][i])
    d2_r12_marginal_data1.append(sin)

# %%
d2_r12_marginal_data1 = np.array(d2_r12_marginal_data1)

# %%
frank = Frank()
frank.tau = d2_r12['tau']
frank.theta = d2_r12['theta']
d2_joint_r12 = frank.probability_density(d2_r12_marginal_data1)
len(d2_joint_r12)
# Out:
# 9000

# %%
ax = sns.distplot(d2_joint_r12, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="values after fusion", ylabel = "probability density")
# Out:
# [Text(0, 0.5, 'probability density'), Text(0.5, 0, 'values after fusion')]

# %%
# No of data points used
N = 9000
  
# normal distribution
data = d2_joint_r12
  
# sort the data in ascending order
x = np.sort(data)
  
# get the cdf values of y
y = np.arange(N) / float(N)
  
# plotting
plt.xlabel('values after fusion')
plt.ylabel('cdf')
  
plt.title('CDF plot of phone gyroscope after fusion using frank copula')
  
plt.plot(x, y)

# %% [markdown]
# ### Joint distribution using pair copula function equation

# %% [markdown]
# joint_p_gyr = f2.f1. joint_c12

# %%
joint_p_gyr = [f2[i]*f1[i]*d2_joint_r12[i] for i in range(len(d2_joint_r12))]

# %%
print(joint_p_gyr)
# Out:
# [0.06624148073559707, 0.08661611878786445, 0.1217506554624162, 0.147983527412276, 0.2950585567810106, 2.143687228102261, 0.7108326429175412, 0.38703497612176413, 0.10789652114307056, 0.06409678984233345, 0.04985744150708894, 0.023353277532210826, 0.038642826740521496, 0.013699926601174488, 0.010515269646653207, 0.010243660788001858, 0.012722034521204696, 0.0196145912266736, 0.02865546085915068, 0.034730728490720654, 0.044414977278399076, 0.1182659653251357, 0.061787672451939765, 0.26884071454332714, 0.5370568303456195, 2.328455046545361, 0.49522209582729404, 0.26824284724872927, 0.22177404188959993, 0.23570090787387246, 0.3011259976702658, 0.4244286571401107, 0.5774029018444489, 0.5267698996465681, 0.35684124598726996, 0.2518695356287664, 0.2179567769990451, 0.21921607597719603, 0.2622742468667613, 0.31524151193886835, 0.37781069823719604, 0.4338965517178908, 0.46240599990146886, 0.49323597634899885, 0.5033460585583464, 0.4668585464500419, 0.38127872420309733, 0.2880816866279828, 0.2
# ...

# %%
print(len(joint_p_gyr))
# Out:
# 9000

# %%
ax = sns.distplot(joint_p_gyr, hist=True, kde=True, 
             bins=int(180/5), color = 'pink', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="values after fusion",ylabel = "probability density")
# Out:
# [Text(0, 0.5, 'probability density'), Text(0.5, 0, 'values after fusion')]

# %%
# No of data points used
N = 9000
  
# normal distribution
data = joint_p_gyr
  
# sort the data in ascending order
x = np.sort(data)
  
# get the cdf values of y
y = np.arange(N) / float(N)
  
# plotting
plt.xlabel('values after fusion')
plt.ylabel('cdf')
  
plt.title('CDF plot of phone gyroscope after fusion using frank copula')
  
plt.plot(x, y)

# %% [markdown]
# ## Fitting Copula

# %% [markdown]
# ### Watch Accelerometer

# %%
regular = VineCopula('regular')
regular.fit(d3)

# %%
parameters = regular.to_dict()
parameters.keys()
# Out:
# dict_keys(['type', 'vine_type', 'fitted', 'n_sample', 'n_var', 'depth', 'truncated', 'trees', 'tau_mat', 'u_matrix', 'unis', 'columns'])

# %%
tau_mat = parameters['tau_mat']
tau_mat
# Out:
# [[1.0, -0.22482344361810017], [-0.22482344361810017, 1.0]]

# %%
u_matrix = parameters['u_matrix']
u_matrix
# Out:
# [[0.48424376768379984, 0.4195725223663746],
#  [0.43304405079730496, 0.4036509348689381],
#  [0.3882785686789089, 0.3819211041978219],
#  [0.3508538757928136, 0.3796709923553381],
#  [0.3053822386196446, 0.368914738345222],
#  [0.27441017091607645, 0.3722674579702104],
#  [0.25735645801964585, 0.3722674579702104],
#  [0.24758194198545638, 0.3722674579702104],
#  [0.24626886553738897, 0.36932926485990675],
#  [0.24923569332585768, 0.38466478957634537],
#  [0.26398635363013007, 0.4006014683916853],
#  [0.28665127683453734, 0.4184771004512928],
#  [0.3194139988243985, 0.4307798232040403],
#  [0.3422082685896578, 0.44301298888143215],
#  [0.3715828580685987, 0.4526225132157037],
#  [0.3909888895211713, 0.46556632775388274],
#  [0.4118992899751018, 0.4643189201673057],
#  [0.4247689871595798, 0.46932556805438574],
#  [0.43304405079730496, 0.4813814974808538],
#  [0.44061328845629016, 0.46681662865990176],
#  [0.44463515876778703, 0.482662522647933],
# ...

# %% [markdown]
# ## Marginal densities

# %%
f1 = regular.unis[0].probability_density(d3['x'])

# %%
f2 = regular.unis[1].probability_density(d3['y'])

# %% [markdown]
# ## Tree Structure

# %%
trees = parameters['trees']
print('Number of the trees:',len(trees))
# Out:
# Number of the trees: 1

# %%
d3_r12 = trees[0]['edges'][0]

# %%
print('r12:',d3_r12['name'])
# Out:
# r12: CopulaTypes.FRANK

# %%
print(d3_r12.keys())
# Out:
# dict_keys(['index', 'L', 'R', 'D', 'parents', 'neighbors', 'name', 'theta', 'tau', 'U', 'likelihood'])

# %%
print(d3_r12['tau'])
# Out:
# -0.22482344361810017

# %%
d3_r12_marginal_data = np.array([d3_r12['U'][0],d3_r12['U'][1]])

# %%
d3_r12_marginal_data1 = []
for i in range(len(d3_r12['U'][0])):
    sin = []
    sin.append(d3_r12_marginal_data[0][i])
    sin.append(d3_r12_marginal_data[1][i])
    d3_r12_marginal_data1.append(sin)

# %%
d3_r12_marginal_data1 = np.array(d3_r12_marginal_data1)

# %%
frank = Frank()
frank.tau = d3_r12['tau']
frank.theta = d3_r12['theta']
d3_joint_r12 = frank.probability_density(d3_r12_marginal_data1)
len(d3_joint_r12)
# Out:
# 9000

# %%
sns.distplot(d3_joint_r12, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %% [markdown]
# ### Joint distribution using pair copula function equation

# %%
joint_w_acc = [f2[i]*f1[i]*d3_joint_r12[i] for i in range(len(d3_joint_r12))]

# %%
print(joint_w_acc)
# Out:
# [0.04490561477561483, 0.034900887616520104, 0.027357680688616697, 0.02552031592882831, 0.021007312492138913, 0.0192451675071268, 0.0175482815898361, 0.016458579140991633, 0.015863867305321664, 0.018537231133214878, 0.02289885030070859, 0.028550171130331405, 0.0337358843260388, 0.03726567763717521, 0.040073495529865576, 0.042649676844965456, 0.04360788824013599, 0.04521510820939344, 0.047289507545762104, 0.046524378966354585, 0.048687795136605906, 0.04904097508564903, 0.04679525800883168, 0.045646600273942635, 0.04370949268300557, 0.044351652600162494, 0.044298968032232794, 0.04355431710953652, 0.044074567218593805, 0.04522625976312317, 0.046661808658087896, 0.04667074309030566, 0.04721668885312653, 0.047583031984445905, 0.04756495817963453, 0.04810632876930205, 0.04774514432396981, 0.048678234214630134, 0.049597490564553766, 0.051413695735229956, 0.05316654831275945, 0.05681036432451622, 0.058814405541106285, 0.061534549815899474, 0.06253922537751726, 0.06156723829643427, 0.057114893
# ...

# %%
print(len(joint_w_acc))
# Out:
# 9000

# %%
ax = sns.distplot(joint_w_acc, hist=True, kde=True, 
             bins=int(180/5), color = 'pink', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="values",ylabel="probabilty density")
# Out:
# [Text(0, 0.5, 'probabilty density'), Text(0.5, 0, 'values')]

# %%
# No of data points used
N = 9000
  
# normal distribution
data = joint_w_acc
  
# sort the data in ascending order
x = np.sort(data)
  
# get the cdf values of y
y = np.arange(N) / float(N)
  
# plotting
plt.xlabel('values')
plt.ylabel('cdf')
  
plt.title('Joint distribution of watch accelerometer')
  
plt.plot(x, y)

# %% [markdown]
# ## Fitting Copula

# %% [markdown]
# ### Watch gyroscope

# %%
regular = VineCopula('regular')
regular.fit(d4)

# %%
parameters = regular.to_dict()
parameters.keys()
# Out:
# dict_keys(['type', 'vine_type', 'fitted', 'n_sample', 'n_var', 'depth', 'truncated', 'trees', 'tau_mat', 'u_matrix', 'unis', 'columns'])

# %%
tau_mat = parameters['tau_mat']
tau_mat
# Out:
# [[1.0, 0.1820785163014578, -0.1954163674717795],
#  [0.1820785163014578, 1.0, 0.06680976123019339],
#  [-0.1954163674717795, 0.06680976123019339, 1.0]]

# %%
u_matrix = parameters['u_matrix']
u_matrix
# Out:
# [[0.32922053900583864, 0.8504984344808493, 0.8503312085870587],
#  [0.2982606365256918, 0.8357883557168523, 0.8494390918453324],
#  [0.2766717579457803, 0.8237742404131725, 0.848654567303029],
#  [0.26355455406328093, 0.8087547936696656, 0.8473013959745298],
#  [0.25400923905130673, 0.7993977228207504, 0.8459381023108493],
#  [0.24956179359534675, 0.7898475848412649, 0.8442201888650115],
#  [0.25050731826732214, 0.7875004739584919, 0.8422551201931563],
#  [0.25822637172123974, 0.7834523962015104, 0.8399187602066096],
#  [0.27263121847947275, 0.7875004739584919, 0.8375551217355217],
#  [0.2959543974772106, 0.7993977228207504, 0.8352825741998329],
#  [0.3447365612583321, 0.8131478911739106, 0.8333462212164062],
#  [0.45158010666058385, 0.8260276604138241, 0.831632901878952],
#  [0.6176962924147512, 0.8357883557168523, 0.8307689065060664],
#  [0.7552200567202976, 0.8460465100401712, 0.8300241359811724],
#  [0.8249136951533304, 0.8553397337231283, 0.8287736225187377],
# ...

# %% [markdown]
# ## Uniform marginal distributions

# %%
F1 = []
F2 = []
F3 = []
for i in range(len(parameters['u_matrix'])):
    F1.append(parameters['u_matrix'][i][0])
    F2.append(parameters['u_matrix'][i][1])
    F3.append(parameters['u_matrix'][i][2])

# %% [markdown]
# ## Marginal pdfs

# %%
f1 = regular.unis[0].probability_density(d4['x'])

# %%
# %matplotlib inline
ax = sns.distplot(f1, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="watch gyroscope - x", ylabel = "marginal density")
# Out:
# [Text(0, 0.5, 'marginal density'), Text(0.5, 0, 'watch gyroscope - x')]

# %%
f2 = regular.unis[1].probability_density(d4['y'])

# %%
# %matplotlib inline
ax = sns.distplot(f2, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="watch gyroscope - y", ylabel = "marginal density")
# Out:
# [Text(0, 0.5, 'marginal density'), Text(0.5, 0, 'watch gyroscope - y')]

# %%
f3 = regular.unis[2].probability_density(d4['z'])

# %%
# %matplotlib inline
az = sns.distplot(f3, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
az.set(xlabel="watch gyroscope - z", ylabel = "marginal density")
# Out:
# [Text(0, 0.5, 'marginal density'), Text(0.5, 0, 'watch gyroscope - z')]

# %% [markdown]
# ## Tree Structure

# %%
trees = parameters['trees']
print('Number of the trees:',len(trees))
# Out:
# Number of the trees: 2

# %%
d4_r12 = trees[0]['edges'][0]
d4_r23 = trees[0]['edges'][1]
d4_r13_2 = trees[1]['edges'][0]

# %%
print('r12:',d4_r12['name'],'r13:',d4_r23['name'])
print('c13|2:',d4_r13_2['name'])
# Out:
# r12: CopulaTypes.FRANK r13: CopulaTypes.CLAYTON
# c13|2: CopulaTypes.FRANK

# %% [markdown]
# ### Frank12

# %%
print(d4_r12.keys())
# Out:
# dict_keys(['index', 'L', 'R', 'D', 'parents', 'neighbors', 'name', 'theta', 'tau', 'U', 'likelihood'])

# %%
print(d4_r12['tau'])
# Out:
# -0.1954163674717795

# %%
d4_r12_marginal_data = np.array([d4_r12['U'][0],d4_r12['U'][1]])

# %%
d4_r12_marginal_data1 = []
for i in range(len(d4_r12['U'][0])):
    sin = []
    sin.append(d4_r12_marginal_data[0][i])
    sin.append(d4_r12_marginal_data[1][i])
    d4_r12_marginal_data1.append(sin)

# %%
d4_r12_marginal_data1 = np.array(d4_r12_marginal_data1)

# %%
frank = Frank()
frank.tau = d4_r12['tau']
frank.theta = d4_r12['theta']
d4_joint_r12 = frank.probability_density(d4_r12_marginal_data1)
len(d4_joint_r12)
# Out:
# 9000

# %%
ax = sns.distplot(d4_joint_r12, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="values", ylabel = "probability density")
ax.set(title="Probability density plot of Frank c13")
# Out:
# [Text(0.5, 1.0, 'Probability density plot of Frank c13')]

# %%
# No of data points used
N = 9000
  
# normal distribution
data = d4_joint_r12
  
# sort the data in ascending order
x = np.sort(data)
  
# get the cdf values of y
y = np.arange(N) / float(N)
  
# plotting
plt.xlabel('values')
plt.ylabel('cdf')
  
plt.title('Joint distribution of Frank c12')
  
plt.plot(x, y)

# %% [markdown]
# ### Clayton23

# %%
d4_r23_marginal_data = np.array([d4_r23['U'][0],d4_r23['U'][1]])

# %%
d4_r23_marginal_data1 = []
for i in range(len(d4_r23['U'][0])):
    sin = []
    sin.append(d4_r23_marginal_data[0][i])
    sin.append(d4_r23_marginal_data[1][i])
    d4_r23_marginal_data1.append(sin)

# %%
d4_r23_marginal_data1 = np.array(d4_r23_marginal_data1)

# %%
clayton = Clayton()
clayton.tau = d4_r23['tau']
clayton.theta = d4_r23['theta']
d4_joint_r23 = clayton.probability_density(d4_r23_marginal_data1)
len(d4_joint_r23)
# Out:
# 9000

# %%
print(d4_joint_r23[0:10])
# Out:
# [0.78726462 0.75326077 0.72914613 0.71856942 0.70960484 0.70861261
#  0.7116043  0.72628038 0.74560712 0.77198768]

# %%
ax = sns.distplot(d4_joint_r23, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="values", ylabel = "probability density")
ax.set(title="Probability density plot of Clayton c23")
# Out:
# [Text(0.5, 1.0, 'Probability density plot of Clayton c23')]

# %%
# No of data points used
N = 9000
  
# normal distribution
data = d4_joint_r23
  
# sort the data in ascending order
x = np.sort(data)
  
# get the cdf values of y
y = np.arange(N) / float(N)
  
# plotting
plt.xlabel('values')
plt.ylabel('cdf')
  
plt.title('Joint distribution of Clayton c23')
  
plt.plot(x, y)

# %% [markdown]
# ### Frank13|2

# %%
d4_r13_2_marginal_data = np.array([d4_r13_2['U'][0],d4_r13_2['U'][1]])
d4_r13_2_marginal_data1 = []
for i in range(len(d4_r13_2['U'][0])):
    sin = []
    sin.append(d4_r13_2_marginal_data[0][i])
    sin.append(d4_r13_2_marginal_data[1][i])
    d4_r13_2_marginal_data1.append(sin)
d4_r13_2_marginal_data1 = np.array(d4_r13_2_marginal_data1)

# %%
frank = Frank()
frank.tau = d4_r13_2['tau']
frank.theta = d4_r13_2['theta']
d4_joint_r13_2 = frank.probability_density(d4_r13_2_marginal_data1)
len(d4_joint_r13_2)
# Out:
# 9000

# %%
print(d4_joint_r13_2[0:10])
# Out:
# [1.17226395 1.16154801 1.15383587 1.14601802 1.14083888 1.13596233
#  1.13374743 1.13126229 1.13193022 1.13624943]

# %%
ax = sns.distplot(d4_joint_r13_2, hist=True, kde=True, 
             bins=int(180/5), color = 'green', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="values", ylabel = "probability density")
ax.set(title="Probability density plot of Frank c13|2")
# Out:
# [Text(0.5, 1.0, 'Probability density plot of Frank c13|2')]

# %%
# No of data points used
N = 9000
  
# normal distribution
data = d4_joint_r13_2
  
# sort the data in ascending order
x = np.sort(data)
  
# get the cdf values of y
y = np.arange(N) / float(N)
  
# plotting
plt.xlabel('values')
plt.ylabel('cdf')
  
plt.title('Joint distribution of Frank c13|2')
  
plt.plot(x, y)

# %% [markdown]
# ### Joint distribution using pair copula function equation

# %% [markdown]
# joint_p_acc = f3.f2.f1. joint_c12 . joint_c13 . joint_c23_1

# %%
joint_w_gyr = [f3[i]*f2[i]*f1[i]*d4_joint_r12[i]*d4_joint_r23[i]*d4_joint_r13_2[i] for i in range(len(F1))]

# %%
print(joint_w_gyr)
# Out:
# [0.027529443537991482, 0.021099055872020107, 0.018111616346761072, 0.01856707020148321, 0.01931769332101137, 0.021097533149614843, 0.021973956872921165, 0.024342815650286502, 0.02623587776937702, 0.029856612856111776, 0.044744511299232285, 0.06953174899247262, 0.06247691323179242, 0.02837904946015476, 0.012180806701444375, 0.008284756280874005, 0.006402760910990184, 0.005260645635712945, 0.004578222496674071, 0.0037691165075370127, 0.00308381565826823, 0.002636716681273503, 0.002364517683922507, 0.002283966893186758, 0.002461425238432081, 0.0028293741124830163, 0.0035181205325369863, 0.004650630875490417, 0.006427569315009919, 0.009737187011604514, 0.018487733732429082, 0.0380951798803265, 0.05573545754146365, 0.05349666153025748, 0.03896203641836757, 0.022077556516305594, 0.01306036478186218, 0.009763612255304435, 0.007556460562587088, 0.005778598352767246, 0.0045889187977792185, 0.003907545853417584, 0.0035159550758601054, 0.003228452428927159, 0.0034557396402303446, 0.004062223647
# ...

# %%
print(len(joint_w_gyr))
# Out:
# 9000

# %%
ax = sns.distplot(joint_w_gyr, hist=True, kde=True, 
             bins=int(180/5), color = 'pink', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set(xlabel="values", ylabel = "probability density")
ax.set(title="Joint Probability density plot of watch gyroscope")
# Out:
# [Text(0.5, 1.0, 'Joint Probability density plot of watch gyroscope')]

# %%
# No of data points used
N = 9000
  
# normal distribution
data = joint_w_gyr
  
# sort the data in ascending order
x = np.sort(data)
  
# get the cdf values of y
y = np.arange(N) / float(N)
  
# plotting
plt.xlabel('values')
plt.ylabel('cdf')
  
plt.title('Joint cumulative distribution of watch gyroscope')
  
plt.plot(x, y)

# %% [markdown]
# ## Saving as csv file

# %%
joint_pdf = [joint_p_acc,joint_p_gyr,joint_w_acc,joint_w_gyr,p_gyr_x,w_acc_z,label1]

# %%
df = pd.DataFrame(joint_pdf).transpose()
df.columns = ['p_acc','p_gyr','w_acc','w_gyr','p_gyr_x','w_acc_z','output']
print(df.head(10))
# Out:
#         p_acc      p_gyr      w_acc      w_gyr     p_gyr_x  w_acc_z  \
# 0  0.00580519  0.0662415  0.0449056  0.0275294   -0.085144   2.2534
# 1  0.00556145  0.0866161  0.0349009  0.0210991 -0.00930786  2.27245
# 2  0.00395667   0.121751  0.0273577  0.0181116   0.0782776  2.21532
# 3   0.0030846   0.147984  0.0255203  0.0185671    0.150909  2.23436
# 4  0.00314165   0.295059  0.0210073  0.0193177    0.194702  2.25816
# 5  0.00376512    2.14369  0.0192452  0.0210975    0.198975  2.21056
# 6  0.00448679   0.710833  0.0175483   0.021974    0.174408  2.28911
# 7  0.00511308   0.387035  0.0164586  0.0243428    0.135956  2.27959
# 8  0.00412557   0.107897  0.0158639  0.0262359    0.100708  2.27959
# 9  0.00187468  0.0640968  0.0185372  0.0298566   0.0814819  2.28435
#
#        output
# 0  stairsdown
# 1  stairsdown
# 2  stairsdown
# 3  stairsdown
# 4  stairsdown
# 5  stairsdown
# 6  stairsdown
# 7  stairsdown
# 8  stairsdown
# 9  stairsdown

# %%
df = pd.concat([df,target],axis=1)
df
# Out:
#            p_acc      p_gyr       w_acc      w_gyr     p_gyr_x  w_acc_z  \
# 0     0.00580519  0.0662415   0.0449056  0.0275294   -0.085144   2.2534
# 1     0.00556145  0.0866161   0.0349009  0.0210991 -0.00930786  2.27245
# 2     0.00395667   0.121751   0.0273577  0.0181116   0.0782776  2.21532
# 3      0.0030846   0.147984   0.0255203  0.0185671    0.150909  2.23436
# 4     0.00314165   0.295059   0.0210073  0.0193177    0.194702  2.25816
# ...          ...        ...         ...        ...         ...      ...
# 8995  0.00110962   0.681533   0.0314434   0.193085   -0.124191  6.15245
# 8996  0.00174176   0.654247   0.0258555   0.241054   -0.129532  6.34288
# 8997  0.00174176   0.673875   0.0170929   0.109025   -0.129532  6.20958
# 8998  0.00240902   0.642786     0.01476  0.0655964   -0.126328   6.2191
# 8999  0.00208906   0.674557  0.00645192   0.129141   -0.123123   6.0739
#
#           output  target
# 0     stairsdown       2
# 1     stairsdown       2
# ...

# %%
df.to_csv('joint_6classes_w_acc_z_and_p_gyr_x_separated.csv') #copy2

# %%
dataset = pd.read_csv('joint_6classes_w_acc_z_and_p_gyr_x_separated.csv',index_col=0) #copy2
X = dataset.iloc[:, [0,1,2,3,4,5]].values
y1 = dataset.iloc[:, -1].values
y2 = dataset.iloc[:,-2].values
print(dataset)
# Out:
#          p_acc     p_gyr     w_acc     w_gyr   p_gyr_x   w_acc_z      output  \
# 0     0.005805  0.066241  0.044906  0.027529 -0.085144  2.253403  stairsdown
# 1     0.005561  0.086616  0.034901  0.021099 -0.009308  2.272446  stairsdown
# 2     0.003957  0.121751  0.027358  0.018112  0.078278  2.215317  stairsdown
# 3     0.003085  0.147984  0.025520  0.018567  0.150909  2.234360  stairsdown
# 4     0.003142  0.295059  0.021007  0.019318  0.194702  2.258163  stairsdown
# ...        ...       ...       ...       ...       ...       ...         ...
# 8995  0.001110  0.681533  0.031443  0.193085 -0.124191  6.152451        bike
# 8996  0.001742  0.654247  0.025856  0.241054 -0.129532  6.342880        bike
# 8997  0.001742  0.673875  0.017093  0.109025 -0.129532  6.209580        bike
# 8998  0.002409  0.642786  0.014760  0.065596 -0.126328  6.219101        bike
# 8999  0.002089  0.674557  0.006452  0.129141 -0.123123  6.073898        bike
#
#       target
# 0          2
# 1          2
# ...

# %%
c = dataset['output']
c
# Out:
# 0       stairsdown
# 1       stairsdown
# 2       stairsdown
# 3       stairsdown
# 4       stairsdown
#            ...
# 8995          bike
# 8996          bike
# 8997          bike
# 8998          bike
# 8999          bike
# Name: output, Length: 9000, dtype: object

# %%
dataset = dataset.drop(['output','target'],axis=1)
dataset
# Out:
#          p_acc     p_gyr     w_acc     w_gyr   p_gyr_x   w_acc_z
# 0     0.005805  0.066241  0.044906  0.027529 -0.085144  2.253403
# 1     0.005561  0.086616  0.034901  0.021099 -0.009308  2.272446
# 2     0.003957  0.121751  0.027358  0.018112  0.078278  2.215317
# 3     0.003085  0.147984  0.025520  0.018567  0.150909  2.234360
# 4     0.003142  0.295059  0.021007  0.019318  0.194702  2.258163
# ...        ...       ...       ...       ...       ...       ...
# 8995  0.001110  0.681533  0.031443  0.193085 -0.124191  6.152451
# 8996  0.001742  0.654247  0.025856  0.241054 -0.129532  6.342880
# 8997  0.001742  0.673875  0.017093  0.109025 -0.129532  6.209580
# 8998  0.002409  0.642786  0.014760  0.065596 -0.126328  6.219101
# 8999  0.002089  0.674557  0.006452  0.129141 -0.123123  6.073898
#
# [9000 rows x 6 columns]

# %%
X
# Out:
# array([[ 5.80519320e-03,  6.62414807e-02,  4.49056148e-02,
#          2.75294435e-02, -8.51440400e-02,  2.25340270e+00],
#        [ 5.56145117e-03,  8.66161188e-02,  3.49008876e-02,
#          2.10990559e-02, -9.30786100e-03,  2.27244570e+00],
#        [ 3.95666996e-03,  1.21750655e-01,  2.73576807e-02,
#          1.81116163e-02,  7.82775900e-02,  2.21531680e+00],
#        ...,
#        [ 1.74175694e-03,  6.73875418e-01,  1.70928899e-02,
#          1.09024500e-01, -1.29531860e-01,  6.20957950e+00],
#        [ 2.40902384e-03,  6.42786321e-01,  1.47600181e-02,
#          6.55963728e-02, -1.26327510e-01,  6.21910100e+00],
#        [ 2.08905832e-03,  6.74556820e-01,  6.45192446e-03,
#          1.29141205e-01, -1.23123170e-01,  6.07389830e+00]])

# %%
y1
# Out:
# array([2, 2, 2, ..., 0, 0, 0], dtype=int64)

# %%
y2
# Out:
# array(['stairsdown', 'stairsdown', 'stairsdown', ..., 'bike', 'bike',
#        'bike'], dtype=object)

# %%
data = pd.DataFrame(X,columns=['p_acc','p_gyr','w_acc','w_gyr','p_gyr_x','w_acc_z'])
data
# Out:
#          p_acc     p_gyr     w_acc     w_gyr   p_gyr_x   w_acc_z
# 0     0.005805  0.066241  0.044906  0.027529 -0.085144  2.253403
# 1     0.005561  0.086616  0.034901  0.021099 -0.009308  2.272446
# 2     0.003957  0.121751  0.027358  0.018112  0.078278  2.215317
# 3     0.003085  0.147984  0.025520  0.018567  0.150909  2.234360
# 4     0.003142  0.295059  0.021007  0.019318  0.194702  2.258163
# ...        ...       ...       ...       ...       ...       ...
# 8995  0.001110  0.681533  0.031443  0.193085 -0.124191  6.152451
# 8996  0.001742  0.654247  0.025856  0.241054 -0.129532  6.342880
# 8997  0.001742  0.673875  0.017093  0.109025 -0.129532  6.209580
# 8998  0.002409  0.642786  0.014760  0.065596 -0.126328  6.219101
# 8999  0.002089  0.674557  0.006452  0.129141 -0.123123  6.073898
#
# [9000 rows x 6 columns]

# %%
df1 = pd.concat((data,target),axis=1)
df1
# Out:
#          p_acc     p_gyr     w_acc     w_gyr   p_gyr_x   w_acc_z  target
# 0     0.005805  0.066241  0.044906  0.027529 -0.085144  2.253403       2
# 1     0.005561  0.086616  0.034901  0.021099 -0.009308  2.272446       2
# 2     0.003957  0.121751  0.027358  0.018112  0.078278  2.215317       2
# 3     0.003085  0.147984  0.025520  0.018567  0.150909  2.234360       2
# 4     0.003142  0.295059  0.021007  0.019318  0.194702  2.258163       2
# ...        ...       ...       ...       ...       ...       ...     ...
# 8995  0.001110  0.681533  0.031443  0.193085 -0.124191  6.152451       0
# 8996  0.001742  0.654247  0.025856  0.241054 -0.129532  6.342880       0
# 8997  0.001742  0.673875  0.017093  0.109025 -0.129532  6.209580       0
# 8998  0.002409  0.642786  0.014760  0.065596 -0.126328  6.219101       0
# 8999  0.002089  0.674557  0.006452  0.129141 -0.123123  6.073898       0
#
# [9000 rows x 7 columns]

# %%
# %matplotlib notebook
sns.heatmap(df1.corr(),annot=True,cmap='viridis')
plt.title('Heatmap after fusion with labels - Rvine',fontsize=16)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
df2 = pd.concat((data,c),axis=1)
df2
# Out:
#          p_acc     p_gyr     w_acc     w_gyr   p_gyr_x   w_acc_z      output
# 0     0.005805  0.066241  0.044906  0.027529 -0.085144  2.253403  stairsdown
# 1     0.005561  0.086616  0.034901  0.021099 -0.009308  2.272446  stairsdown
# 2     0.003957  0.121751  0.027358  0.018112  0.078278  2.215317  stairsdown
# 3     0.003085  0.147984  0.025520  0.018567  0.150909  2.234360  stairsdown
# 4     0.003142  0.295059  0.021007  0.019318  0.194702  2.258163  stairsdown
# ...        ...       ...       ...       ...       ...       ...         ...
# 8995  0.001110  0.681533  0.031443  0.193085 -0.124191  6.152451        bike
# 8996  0.001742  0.654247  0.025856  0.241054 -0.129532  6.342880        bike
# 8997  0.001742  0.673875  0.017093  0.109025 -0.129532  6.209580        bike
# 8998  0.002409  0.642786  0.014760  0.065596 -0.126328  6.219101        bike
# 8999  0.002089  0.674557  0.006452  0.129141 -0.123123  6.073898        bike
#
# [9000 rows x 7 columns]

# %%
import ppscore as pps
x = pps.matrix(df2,sample=9000)[['x','y','ppscore']].pivot(columns='x',index='y',values='ppscore')

# %%
# %matplotlib notebook
sns.heatmap(x,annot=True,cmap='Blues')
plt.title('Heatmap after fusion with labels-Rvine',fontsize=16)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ## Classification

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y2, test_size = 0.1, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier 
classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Predicting the Test set results
y_pred  = classifier.predict(X_test)

# %%
y_pred
# Out:
# array(['sit', 'stairsup', 'bike', 'bike', 'stairsup', 'sit', 'stairsdown',
#        'bike', 'stairsdown', 'stairsup', 'stand', 'stairsdown', 'bike',
#        'bike', 'stand', 'bike', 'stand', 'stairsup', 'bike', 'sit', 'sit',
#        'bike', 'stairsup', 'bike', 'sit', 'stairsdown', 'stairsdown',
#        'sit', 'bike', 'stand', 'stairsdown', 'walk', 'sit', 'stairsdown',
#        'walk', 'bike', 'stairsdown', 'bike', 'stairsup', 'stairsdown',
#        'walk', 'stairsup', 'bike', 'stairsup', 'sit', 'stairsup', 'stand',
#        'bike', 'stand', 'bike', 'sit', 'sit', 'stairsdown', 'stairsdown',
#        'sit', 'stand', 'stand', 'stairsup', 'bike', 'stairsup', 'bike',
#        'bike', 'walk', 'stairsup', 'stand', 'walk', 'stairsdown',
#        'stairsup', 'stairsup', 'stairsdown', 'sit', 'stand', 'bike',
#        'stairsdown', 'bike', 'bike', 'stand', 'bike', 'sit', 'bike',
#        'stairsdown', 'stand', 'stand', 'sit', 'walk', 'stairsdown',
# ...

# %%
y_test
# Out:
# array(['sit', 'stairsup', 'bike', 'bike', 'stairsup', 'sit', 'stairsdown',
#        'bike', 'stairsdown', 'stairsup', 'stand', 'stairsdown', 'bike',
#        'bike', 'stand', 'bike', 'stand', 'stairsup', 'bike', 'sit', 'sit',
#        'bike', 'stairsup', 'bike', 'sit', 'stairsdown', 'stairsdown',
#        'sit', 'bike', 'stand', 'stairsdown', 'walk', 'sit', 'stairsdown',
#        'walk', 'bike', 'stairsdown', 'bike', 'stairsup', 'stairsdown',
#        'walk', 'stairsup', 'bike', 'stairsup', 'sit', 'stairsup', 'stand',
#        'bike', 'stand', 'bike', 'sit', 'sit', 'stairsdown', 'stairsdown',
#        'sit', 'stand', 'stand', 'stairsup', 'bike', 'stairsup', 'bike',
#        'bike', 'walk', 'stairsup', 'stand', 'walk', 'stairsdown',
#        'stairsup', 'stairsup', 'stairsdown', 'sit', 'stand', 'bike',
#        'stairsdown', 'bike', 'bike', 'stand', 'bike', 'sit', 'bike',
#        'stairsdown', 'stand', 'stand', 'sit', 'walk', 'stairsdown',
# ...

# %%
# Making the Confusion Matrix and accuracy_Score
from sklearn.metrics import confusion_matrix,accuracy_score,f1_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9822222222222222

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[164,   0,   1,   0,   0,   0],
#        [  0, 149,   0,   0,   0,   0],
#        [  0,   0, 135,   0,   0,  10],
#        [  0,   0,   0, 141,   0,   0],
#        [  0,   0,   0,   0, 158,   0],
#        [  0,   0,   5,   0,   0, 137]], dtype=int64)

# %%
f1_score(y_test, y_pred, average='macro')
# Out:
# 0.9815188860318802
